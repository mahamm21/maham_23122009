# %% [markdown]
# <a href="https://colab.research.google.com/github/mahamm21/maham_23122009/blob/main/Maham_lab3_sep8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai
from google import genai

# %%
from google import genai
client = genai.Client(api_key="")

# %%
MODEL = "models/gemini-3.5-flash"

# %%
def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# Gemini Travel Agent Started (type 'exit' to stop)
#
# You: Hello
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Agent:
#  Hello and welcome! As your dedicated travel agent for Pakistan Tourism, I am thrilled to help you plan an unforgettable trip.
#
# Since you are looking for a student-friendly adventure, I have designed a budget-friendly travel plan to **Hunza Valley**, the crown jewel of Gilgit-Baltistan. Hunza is incredibly safe, breathtakingly beautiful, and highly accessible for students on a budget.
#
# Here is your detailed travel plan:
#
# ---
#
# ### 1. Destination Overview
# ...

# %%
# !pip install -U google-genai
from google import genai
from google import genai
client = genai.Client(api_key="AQ.Ab8RN6Jjcf2D0UqRRR7JguArYiZr_CDFoUy3kY5O4K1VUX7fjA")
MODEL = "models/gemini-3.5-flash"

def exam_paper_checker_agent(user_input):

    prompt = f"""
Yor are a professional exam paper checker agent for MCQ's paper.
Provide columns with following heading clearly:
1. Number of wrong answers
2. Number of correct answers
3. Correct MCQ's key
4. Total Obtained Marks

Make sure to check the paper correctly and reward marks purely based on the correct answers.
Students answer:{user_input}

Now check the student's answer:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text

print("Exam Paper Checker Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye")
        break

    try:
        reply = exam_paper_checker_agent(user)
        print("\nChecker:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
# Exam Paper Checker Agent Started (type 'exit' to stop)
#
# You: Correct Key: 1.A, 2.B, 3.C, 4.D, 5.A Student Answers: 1.A, 2.C, 3.C, 4.A, 5.A
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Checker:
#  Here is the evaluation of the student's MCQ paper based on the provided correct key:
#
# | 1. Number of wrong answers | 2. Number of correct answers | 3. Correct MCQ's key | 4. Total Obtained Marks |
# | :--- | :--- | :--- | :--- |
# | **2** <br>*(Q2 and Q4 are incorrect)* | **3** <br>*(Q1, Q3, and Q5 are correct)* | 1.A, 2.B, 3.C, 4.D, 5.A | **3 / 5** <br>*(Assuming 1 mark per correct answer)* |
#
# ### Detailed Evaluation Breakdown:
# * **Question 1:** Student Answer: **A** | Correct Key: **A** ➔ **Correct**
# ...
